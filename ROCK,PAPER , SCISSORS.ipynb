# %% [markdown]
# <a href="https://colab.research.google.com/github/nkanyezi03/nkanyezi03/blob/main/ROCK%2CPAPER%20%2C%20SCISSORS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
objects_=int{
    rock=1
    scissor=2
    paper=3
}
user_choose= int input(objects_)

print("Choose 1 for rock , 2 for scissor, 3 for paper")

random.randint(1,3)

comp_choose= int random.randint(1,3)
if(user_choose== 1 && comp_choose ==1 ,user_choose==2 && comp_choose== 2 ,
   user_choose==3 && comp_choose==3)
{
    print("The result is a draw!")
}
else (user_choose==1 && comp_choose==3 ){
    print("Rock has won!")
}
else if (user_choose==2 && comp_choose==3){
    print("Paper has won!")
}

if(user_choose==2 && comp_choose==3){
    print("Scissors has won!")
}
else (user_choose >1 || <3)
print("Invalid input!")
